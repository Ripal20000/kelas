# %% [markdown]
# # **Sesi 2: Pengenalan dengan NumPy dan Arrays**

# %% [markdown]
# ## **Praktek: Memasukkan dan mengakses data pada array​**

# %%
#import library numpy
import numpy as np

# %%
#inisiasi array A
A = np.array([1, 3, 6, 3])

# %%
A.dtype

# %%
#inisiasi array A0 dengan int32
A0 = np.array([1, 3, 6, 3], dtype='int32')
A0.dtype

# %% [markdown]
# Array a memiliki tipe data int32 dan int64 yang keduanya sama-sama bertipekan integer. Perbedaan keduanya pada kapasitas penyimpanan data.
# *   Pada int32 mampu menampung hingga (-2,147,483,648 to +2,147,483,647)
# *   Pada int64 mampu menampung hingga (-9,223,372,036,854,775,808 to +9,223,372,036,854,775,807)

# %%
#upcasting array B
B = np.array([1, 3, 6, 3.0])
B

# %%
#akses elemen array pertama (indeks=0)
print(A[0])

# %%
#inisiasi array A1
A1 = np.array(["i"])
type(A1)
print(A1.dtype)

#inisiasi array A2
A2 = np.array(["i", 2])
type(A1)
print(A2.dtype)

#<U1 = big-endian byte ordering unsigned ints size 2 byte, order in 1
#<U1 = big-endian byte ordering unsigned ints size 2 byte, order in 1

# %% [markdown]
# *   b1, i1, i2, i4, i8, u1, u2, u4, u8, f2, f4, f8, c8, c16, a
#    (representing bytes, ints, unsigned ints, floats, complex and
#     fixed-length strings of specified byte lengths)
# *   int8,…,uint8,…,float16, float32, float64, complex64, complex128
#    (this time with bit sizes)
# *  '>' represents big-endian byte ordering and < represents little-endian encoding.

# %%
#akses elemen array ke-2 hingga ke-3
print(A[1:3])

# %% [markdown]
# ## **Praktek: Membuat array otomatis dengan metode numpy​**

# %%
a = np.empty([3,2], dtype = int)
print(a)

# %%
#satu dimensi
b = np.zeros(5) 
print (b)

# %%
#multidimensi
c = np.zeros((5,5)) 
print (c)

# %%
#satu dimensi
d = np.ones(5) 
print (d)

# %%
#satu dimensi
e = np.arange(5,10) 
print(e)

# %%
#satu dimensi
f = np.linspace(5,10) 
print(f)
f.ndim

# %% [markdown]
# ## **Praktek: Merubah dan menghapus elemen data pada array​**

# %%
#import library numpy
import numpy as np

# %%
#inisiasi array A
A = np.array([1, 3, 6, 3])

# %%
#merubah elemen array A yang >5 menjadi 0
A[A > 5] = 0

# %%
#print hasil array yang telah dirubah
print(A)
# Out:
# [1 3 6 3]

# %%
#menghapus elemen A pada indeks ke-0 sampai batas indeks 3 dengan np.delete(nama_array, indeks)
A1 = np.delete(A, np.where(A[0:3]))

# %%
#print hasil array yang telah dihapus elemen pertamanya (elemen dengan indeks = 0)
print(A1)
# Out:
# [3]

# %% [markdown]
# ## **Praktek: Melakukan pengurutan dan penyaringan data pada array​**

# %%
#import library numpy
import numpy as np

# %%
#inisiasi array A
A = np.array([1, 3, 6, 3])

# %%
#urutkan array A
A2 = np.sort(A)

# %%
#print hasil array yang telah diurutkan
print(A2)

# %%
#filter elemen array berdasarkan indeks
x = [True, False, True, False]
A3 = A[x]

# %%
#print hasil array yang telah difilter
print(A3)

# %%
#buat filter yang hanya angka>3 yang disertakan
filter_arr = A>3
A4 = A[filter_arr]

# %%
#print hasil array yang telah difilter
print(A4)

# %% [markdown]
# ## **Praktek: Membuat array 2 dimensi secara manual​**

# %%
#import library numpy
import numpy as np

# %%
#buat array 2D dengan nama A5
A5 = np.array([[1, 3, 6, 3], [3, 6, 1, 3]])

# %%
#print A5 dan cek dimensi array
print(A5)
print('dimensi array: ', A5.ndim)

# %% [markdown]
# ## **Praktek: Konversi array 1 dimensi menjadi 2 dimensi​**

# %%
#import library numpy 
import numpy as np

# %%
#inisiasi array A dan cek dimensinya
A = np.array([1, 3, 6, 3])
print(A)
print('dimensi array: ', A.ndim)

# %%
#ubah menjadi array 2x2 dan cek dimensinya
A6 = A.reshape(2, 2)
print(A6)
print('dimensi array: ', A6.ndim)
